# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
classified_df_filename = 'classified_df.csv'
top_250_words_filename = 'top_250_words_df.csv'

# %%
df, df_words = pd.read_csv(classified_df_filename), pd.read_csv(top_250_words_filename)

# %%
df.drop(df.columns[0], axis=1, inplace=True)

# %%
df.groupby('cluster').size()
# Out:
# cluster
# 0    7587
# 1    4629
# 2    8650
# dtype: int64

# %%
fig = plt.figure(figsize=(7,7))
ax = fig.gca()
df[['roberta_neg', 'roberta_neu', 'roberta_pos']].hist(ax=ax)
plt.show()
# Out:
# C:\Users\tonch\AppData\Local\Temp\ipykernel_113788\3029712696.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df[['roberta_neg', 'roberta_neu', 'roberta_pos']].hist(ax=ax)

# %%
df.cluster.plot(kind='pie')
# Out:
# <AxesSubplot: ylabel='cluster'>

# %%
df[['roberta_neg', 'roberta_neu', 'roberta_pos']].corr(method='pearson').plot()
# Out:
# <AxesSubplot: >
